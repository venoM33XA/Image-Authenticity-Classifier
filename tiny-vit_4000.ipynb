# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17.3->scikit-learn) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17.3->scikit-learn) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17.3->scikit-learn) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17.3->scikit-learn) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17.3->scikit-learn) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.17.3->scikit-learn) (2.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.17.3->scikit-learn) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.17.3->scikit-learn) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.17.3->scikit-learn) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.17.3->scikit-learn) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.17.3->scikit-learn) (2024.2.0)

# %%
import warnings 
import sklearn.exceptions 

import glob 

from PIL import Image 

import torch
import timm
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import CosineAnnealingLR

from sklearn.metrics import classification_report

warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=sklearn.exceptions.UndefinedMetricWarning)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# !pip install torchattacks 
import torchattacks
import cv2
import numpy as np
import os
import torch
import torchvision.transforms as transforms
from shutil import copyfile
from torchvision import datasets, models
from torch.utils.data import DataLoader

# Define paths
INPUT_PATH = "/kaggle/input/cifake-real-and-ai-generated-synthetic-images/train"  # Set the correct path
OUTPUT_PATH = "/kaggle/working/train"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load CIFAKE Dataset
transform = transforms.Compose([transforms.ToTensor()])
dataset = datasets.ImageFolder(root=INPUT_PATH, transform=transform)

# Select 4000 images
subset_indices = np.random.choice(len(dataset), 4000, replace=False)
subset = torch.utils.data.Subset(dataset, subset_indices)

# Create DataLoader
dataloader = DataLoader(subset, batch_size=1, shuffle=False)

# Debugging: Ensure cuDNN errors are visible
torch.backends.cudnn.enabled = False

# ✅ Load a Pretrained Model for Binary Classification
model = models.resnet18(pretrained=True)
model.fc = torch.nn.Linear(512, 2)  # Adjust output for 2 classes (real/fake)
model = model.to(device)
model.eval()  # Set model to evaluation mode

# Initialize PGD Attack
attack_pgd = torchattacks.PGD(model, eps=8/255, alpha=2/255, steps=10)

# Ensure output folders exist
os.makedirs(os.path.join(OUTPUT_PATH, "real"), exist_ok=True)
os.makedirs(os.path.join(OUTPUT_PATH, "fake"), exist_ok=True)

# Process images
for i, (img_tensor, label) in enumerate(dataloader):
    img_tensor = img_tensor.to(device)
    label = label.to(device).long().squeeze()  # Ensure labels are long & scalar

    # Ensure labels are valid
    if label.item() not in [0, 1]:
        print(f"⚠️ Invalid label at index {i}: {label.item()} (Skipping)")
        continue

    category = "real" if label.item() == 0 else "fake"
    filename = f"image_{i}.jpg"

    if i < 2000:
        # Apply PGD Attack
        try:
            pgd_perturbed = attack_pgd(img_tensor, label.unsqueeze(0).to(device))  # Fix label shape
            pgd_path = os.path.join(OUTPUT_PATH, category, f"image_{i}_PGD.jpg")
            
            # Ensure image is converted properly
            pgd_perturbed = torch.clamp(pgd_perturbed.cpu().squeeze(), 0, 1)  # Clamp to valid range
            transforms.ToPILImage()(pgd_perturbed).convert("RGB").save(pgd_path)

            print(f"Processed {i+1}/4000: {filename} → {category} (Perturbed & Saved)")
        except RuntimeError as e:
            print(f"⚠️ PGD Attack Failed for {filename}: {e}")
    else:
        # Save original image without attack
        original_path = os.path.join(OUTPUT_PATH, category, filename)
        img_tensor = torch.clamp(img_tensor.cpu().squeeze(), 0, 1)  # Clamp to valid range
        transforms.ToPILImage()(img_tensor).convert("RGB").save(original_path)

        print(f"Processed {i+1}/4000: {filename} → {category} (Copied without attack)")
# Out:
# Collecting torchattacks
#   Downloading torchattacks-3.5.1-py3-none-any.whl.metadata (927 bytes)
# Requirement already satisfied: torch>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from torchattacks) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from torchattacks) (0.20.1+cu121)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from torchattacks) (1.13.1)
# Requirement already satisfied: tqdm>=4.56.1 in /usr/local/lib/python3.10/dist-packages (from torchattacks) (4.67.1)
# Collecting requests~=2.25.1 (from torchattacks)
#   Downloading requests-2.25.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: numpy>=1.19.4 in /usr/local/lib/python3.10/dist-packages (from torchattacks) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.4->torchattacks) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.4->torchattacks) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.4->torchattacks) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.4->torchattacks) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.4->torchattacks) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.4->torchattacks) (2.4.1)
# Collecting chardet<5,>=3.0.2 (from requests~=2.25.1->torchattacks)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting idna<3,>=2.5 (from requests~=2.25.1->torchattacks)
#   Downloading idna-2.10-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting urllib3<1.27,>=1.21.1 (from requests~=2.25.1->torchattacks)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests~=2.25.1->torchattacks) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->torchattacks) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->torchattacks) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->torchattacks) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->torchattacks) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->torchattacks) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->torchattacks) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.7.1->torchattacks) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.8.2->torchattacks) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7.1->torchattacks) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.19.4->torchattacks) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.19.4->torchattacks) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.19.4->torchattacks) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.19.4->torchattacks) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.19.4->torchattacks) (2024.2.0)
# Downloading torchattacks-3.5.1-py3-none-any.whl (142 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.0/142.0 kB 6.8 MB/s eta 0:00:00
# Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 3.7 MB/s eta 0:00:00
# Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 10.8 MB/s eta 0:00:00
# Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.6 MB/s eta 0:00:00
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 10.0 MB/s eta 0:00:00
# Installing collected packages: urllib3, idna, chardet, requests, torchattacks
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.3.0
#     Uninstalling urllib3-2.3.0:
#       Successfully uninstalled urllib3-2.3.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.29.0 requires requests>=2.27.1, but you have requests 2.25.1 which is incompatible.
# datasets 3.3.1 requires requests>=2.32.2, but you have requests 2.25.1 which is incompatible.
# docker 7.1.0 requires requests>=2.26.0, but you have requests 2.25.1 which is incompatible.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.12.0 which is incompatible.
# google-cloud-bigtable 2.27.0 requires google-api-core[grpc]<3.0.0dev,>=2.16.0, but you have google-api-core 1.34.1 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.5, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.25.1 which is incompatible.
# google-genai 0.2.2 requires requests<3.0.0dev,>=2.28.1, but you have requests 2.25.1 which is incompatible.
# jupyterlab-server 2.27.3 requires requests>=2.31, but you have requests 2.25.1 which is incompatible.
# langchain 0.3.12 requires async-timeout<5.0.0,>=4.0.0; python_version < "3.11", but you have async-timeout 5.0.1 which is incompatible.
# libpysal 4.9.2 requires requests>=2.27, but you have requests 2.25.1 which is incompatible.
# pandas-gbq 0.25.0 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# sphinx 8.1.3 requires requests>=2.30.0, but you have requests 2.25.1 which is incompatible.
# tensorflow-decision-forests 1.10.0 requires tensorflow==2.17.0, but you have tensorflow 2.17.1 which is incompatible.
# tiktoken 0.9.0 requires requests>=2.26.0, but you have requests 2.25.1 which is incompatible.
# tweepy 4.14.0 requires requests<3,>=2.27.0, but you have requests 2.25.1 which is incompatible.
# yfinance 0.2.50 requires requests>=2.31, but you have requests 2.25.1 which is incompatible.
# Successfully installed chardet-4.0.0 idna-2.10 requests-2.25.1 torchattacks-3.5.1 urllib3-1.26.20
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 200MB/s]
# Processed 1/4000: image_0.jpg → real (Perturbed & Saved)
# Processed 2/4000: image_1.jpg → fake (Perturbed & Saved)
# Processed 3/4000: image_2.jpg → fake (Perturbed & Saved)
# Processed 4/4000: image_3.jpg → fake (Perturbed & Saved)
# Processed 5/4000: image_4.jpg → real (Perturbed & Saved)
# Processed 6/4000: image_5.jpg → fake (Perturbed & Saved)
# Processed 7/4000: image_6.jpg → fake (Perturbed & Saved)
# Processed 8/4000: image_7.jpg → fake (Perturbed & Saved)
# Processed 9/4000: image_8.jpg → fake (Perturbed & Saved)
# Processed 10/4000: image_9.jpg → real (Perturbed & Saved)
# Processed 11/4000: image_10.jpg → fake (Perturbed & Saved)
# Processed 12/4000: image_11.jpg → fake (Perturbed & Saved)
# Processed 13/4000: image_12.jpg → fake (Perturbed & Saved)
# Processed 14/4000: image_13.jpg → fake (Perturbed & Saved)
# Processed 15/4000: image_14.jpg → fake (Perturbed & Saved)
# Processed 16/4000: image_15.jpg → fake (Perturbed & Saved)
# Processed 17/4000: image_16.jpg → real (Perturbed & Saved)
# Processed 18/4000: image_17.jpg → fake (Perturbed & Saved)
# Processed 19/4000: image_18.jpg → real (Perturbed & Saved)
# Processed 20/4000: image_19.jpg → real (Perturbed & Saved)
# Processed 21/4000: image_20.jpg → real (Perturbed & Saved)
# Processed 22/4000: image_21.jpg → real (Perturbed & Saved)
# Processed 23/4000: image_22.jpg → fake (Perturbed & Saved)
# Processed 24/4000: image_23.jpg → real (Perturbed & Saved)
# Processed 25/4000: image_24.jpg → fake (Perturbed & Saved)
# Processed 26/4000: image_25.jpg → real (Perturbed & Saved)
# Processed 27/4000: image_26.jpg → fake (Perturbed & Saved)
# Processed 28/4000: image_27.jpg → real (Perturbed & Saved)
# Processed 29/4000: image_28.jpg → real (Perturbed & Saved)
# Processed 30/4000: image_29.jpg → real (Perturbed & Saved)
# Processed 31/4000: image_30.jpg → real (Perturbed & Saved)
# Processed 32/4000: image_31.jpg → real (Perturbed & Saved)
# Processed 33/4000: image_32.jpg → real (Perturbed & Saved)
# Processed 34/4000: image_33.jpg → fake (Perturbed & Saved)
# Processed 35/4000: image_34.jpg → fake (Perturbed & Saved)
# Processed 36/4000: image_35.jpg → fake (Perturbed & Saved)
# Processed 37/4000: image_36.jpg → real (Perturbed & Saved)
# Processed 38/4000: image_37.jpg → fake (Perturbed & Saved)
# Processed 39/4000: image_38.jpg → fake (Perturbed & Saved)
# Processed 40/4000: image_39.jpg → real (Perturbed & Saved)
# Processed 41/4000: image_40.jpg → real (Perturbed & Saved)
# Processed 42/4000: image_41.jpg → fake (Perturbed & Saved)
# Processed 43/4000: image_42.jpg → real (Perturbed & Saved)
# Processed 44/4000: image_43.jpg → real (Perturbed & Saved)
# Processed 45/4000: image_44.jpg → fake (Perturbed & Saved)
# Processed 46/4000: image_45.jpg → fake (Perturbed & Saved)
# Processed 47/4000: image_46.jpg → fake (Perturbed & Saved)
# Processed 48/4000: image_47.jpg → real (Perturbed & Saved)
# Processed 49/4000: image_48.jpg → real (Perturbed & Saved)
# Processed 50/4000: image_49.jpg → fake (Perturbed & Saved)
# Processed 51/4000: image_50.jpg → fake (Perturbed & Saved)
# Processed 52/4000: image_51.jpg → real (Perturbed & Saved)
# Processed 53/4000: image_52.jpg → fake (Perturbed & Saved)
# Processed 54/4000: image_53.jpg → fake (Perturbed & Saved)
# Processed 55/4000: image_54.jpg → fake (Perturbed & Saved)
# Processed 56/4000: image_55.jpg → real (Perturbed & Saved)
# Processed 57/4000: image_56.jpg → fake (Perturbed & Saved)
# Processed 58/4000: image_57.jpg → real (Perturbed & Saved)
# Processed 59/4000: image_58.jpg → real (Perturbed & Saved)
# Processed 60/4000: image_59.jpg → real (Perturbed & Saved)
# Processed 61/4000: image_60.jpg → real (Perturbed & Saved)
# Processed 62/4000: image_61.jpg → real (Perturbed & Saved)
# Processed 63/4000: image_62.jpg → real (Perturbed & Saved)
# Processed 64/4000: image_63.jpg → fake (Perturbed & Saved)
# Processed 65/4000: image_64.jpg → real (Perturbed & Saved)
# Processed 66/4000: image_65.jpg → real (Perturbed & Saved)
# Processed 67/4000: image_66.jpg → fake (Perturbed & Saved)
# Processed 68/4000: image_67.jpg → fake (Perturbed & Saved)
# Processed 69/4000: image_68.jpg → fake (Perturbed & Saved)
# Processed 70/4000: image_69.jpg → fake (Perturbed & Saved)
# Processed 71/4000: image_70.jpg → real (Perturbed & Saved)
# Processed 72/4000: image_71.jpg → fake (Perturbed & Saved)
# Processed 73/4000: image_72.jpg → fake (Perturbed & Saved)
# Processed 74/4000: image_73.jpg → real (Perturbed & Saved)
# Processed 75/4000: image_74.jpg → real (Perturbed & Saved)
# Processed 76/4000: image_75.jpg → fake (Perturbed & Saved)
# Processed 77/4000: image_76.jpg → fake (Perturbed & Saved)
# Processed 78/4000: image_77.jpg → fake (Perturbed & Saved)
# Processed 79/4000: image_78.jpg → real (Perturbed & Saved)
# Processed 80/4000: image_79.jpg → real (Perturbed & Saved)
# Processed 81/4000: image_80.jpg → real (Perturbed & Saved)
# Processed 82/4000: image_81.jpg → real (Perturbed & Saved)
# Processed 83/4000: image_82.jpg → fake (Perturbed & Saved)
# Processed 84/4000: image_83.jpg → real (Perturbed & Saved)
# Processed 85/4000: image_84.jpg → real (Perturbed & Saved)
# Processed 86/4000: image_85.jpg → real (Perturbed & Saved)
# Processed 87/4000: image_86.jpg → fake (Perturbed & Saved)
# Processed 88/4000: image_87.jpg → real (Perturbed & Saved)
# Processed 89/4000: image_88.jpg → fake (Perturbed & Saved)
# Processed 90/4000: image_89.jpg → real (Perturbed & Saved)
# Processed 91/4000: image_90.jpg → fake (Perturbed & Saved)
# Processed 92/4000: image_91.jpg → real (Perturbed & Saved)
# Processed 93/4000: image_92.jpg → real (Perturbed & Saved)
# Processed 94/4000: image_93.jpg → real (Perturbed & Saved)
# Processed 95/4000: image_94.jpg → real (Perturbed & Saved)
# Processed 96/4000: image_95.jpg → fake (Perturbed & Saved)
# Processed 97/4000: image_96.jpg → fake (Perturbed & Saved)
# Processed 98/4000: image_97.jpg → fake (Perturbed & Saved)
# Processed 99/4000: image_98.jpg → real (Perturbed & Saved)
# Processed 100/4000: image_99.jpg → fake (Perturbed & Saved)
# Processed 101/4000: image_100.jpg → fake (Perturbed & Saved)
# Processed 102/4000: image_101.jpg → fake (Perturbed & Saved)
# Processed 103/4000: image_102.jpg → real (Perturbed & Saved)
# Processed 104/4000: image_103.jpg → fake (Perturbed & Saved)
# Processed 105/4000: image_104.jpg → real (Perturbed & Saved)
# Processed 106/4000: image_105.jpg → real (Perturbed & Saved)
# Processed 107/4000: image_106.jpg → fake (Perturbed & Saved)
# Processed 108/4000: image_107.jpg → fake (Perturbed & Saved)
# Processed 109/4000: image_108.jpg → real (Perturbed & Saved)
# Processed 110/4000: image_109.jpg → real (Perturbed & Saved)
# Processed 111/4000: image_110.jpg → real (Perturbed & Saved)
# Processed 112/4000: image_111.jpg → real (Perturbed & Saved)
# Processed 113/4000: image_112.jpg → real (Perturbed & Saved)
# Processed 114/4000: image_113.jpg → fake (Perturbed & Saved)
# Processed 115/4000: image_114.jpg → fake (Perturbed & Saved)
# Processed 116/4000: image_115.jpg → real (Perturbed & Saved)
# Processed 117/4000: image_116.jpg → fake (Perturbed & Saved)
# Processed 118/4000: image_117.jpg → real (Perturbed & Saved)
# Processed 119/4000: image_118.jpg → fake (Perturbed & Saved)
# Processed 120/4000: image_119.jpg → real (Perturbed & Saved)
# Processed 121/4000: image_120.jpg → real (Perturbed & Saved)
# Processed 122/4000: image_121.jpg → real (Perturbed & Saved)
# Processed 123/4000: image_122.jpg → fake (Perturbed & Saved)
# Processed 124/4000: image_123.jpg → real (Perturbed & Saved)
# Processed 125/4000: image_124.jpg → real (Perturbed & Saved)
# Processed 126/4000: image_125.jpg → real (Perturbed & Saved)
# Processed 127/4000: image_126.jpg → fake (Perturbed & Saved)
# Processed 128/4000: image_127.jpg → real (Perturbed & Saved)
# Processed 129/4000: image_128.jpg → real (Perturbed & Saved)
# Processed 130/4000: image_129.jpg → real (Perturbed & Saved)
# Processed 131/4000: image_130.jpg → real (Perturbed & Saved)
# Processed 132/4000: image_131.jpg → fake (Perturbed & Saved)
# Processed 133/4000: image_132.jpg → real (Perturbed & Saved)
# Processed 134/4000: image_133.jpg → real (Perturbed & Saved)
# Processed 135/4000: image_134.jpg → fake (Perturbed & Saved)
# Processed 136/4000: image_135.jpg → fake (Perturbed & Saved)
# Processed 137/4000: image_136.jpg → real (Perturbed & Saved)
# Processed 138/4000: image_137.jpg → real (Perturbed & Saved)
# Processed 139/4000: image_138.jpg → real (Perturbed & Saved)
# Processed 140/4000: image_139.jpg → fake (Perturbed & Saved)
# Processed 141/4000: image_140.jpg → real (Perturbed & Saved)
# Processed 142/4000: image_141.jpg → fake (Perturbed & Saved)
# Processed 143/4000: image_142.jpg → real (Perturbed & Saved)
# Processed 144/4000: image_143.jpg → real (Perturbed & Saved)
# Processed 145/4000: image_144.jpg → fake (Perturbed & Saved)
# Processed 146/4000: image_145.jpg → real (Perturbed & Saved)
# Processed 147/4000: image_146.jpg → real (Perturbed & Saved)
# Processed 148/4000: image_147.jpg → fake (Perturbed & Saved)
# Processed 149/4000: image_148.jpg → real (Perturbed & Saved)
# Processed 150/4000: image_149.jpg → fake (Perturbed & Saved)
# Processed 151/4000: image_150.jpg → fake (Perturbed & Saved)
# Processed 152/4000: image_151.jpg → fake (Perturbed & Saved)
# Processed 153/4000: image_152.jpg → fake (Perturbed & Saved)
# Processed 154/4000: image_153.jpg → real (Perturbed & Saved)
# Processed 155/4000: image_154.jpg → real (Perturbed & Saved)
# Processed 156/4000: image_155.jpg → real (Perturbed & Saved)
# Processed 157/4000: image_156.jpg → real (Perturbed & Saved)
# Processed 158/4000: image_157.jpg → fake (Perturbed & Saved)
# Processed 159/4000: image_158.jpg → fake (Perturbed & Saved)
# Processed 160/4000: image_159.jpg → fake (Perturbed & Saved)
# Processed 161/4000: image_160.jpg → real (Perturbed & Saved)
# Processed 162/4000: image_161.jpg → real (Perturbed & Saved)
# Processed 163/4000: image_162.jpg → fake (Perturbed & Saved)
# Processed 164/4000: image_163.jpg → fake (Perturbed & Saved)
# Processed 165/4000: image_164.jpg → real (Perturbed & Saved)
# Processed 166/4000: image_165.jpg → fake (Perturbed & Saved)
# Processed 167/4000: image_166.jpg → real (Perturbed & Saved)
# Processed 168/4000: image_167.jpg → fake (Perturbed & Saved)
# Processed 169/4000: image_168.jpg → real (Perturbed & Saved)
# Processed 170/4000: image_169.jpg → real (Perturbed & Saved)
# Processed 171/4000: image_170.jpg → fake (Perturbed & Saved)
# Processed 172/4000: image_171.jpg → fake (Perturbed & Saved)
# Processed 173/4000: image_172.jpg → real (Perturbed & Saved)
# Processed 174/4000: image_173.jpg → real (Perturbed & Saved)
# Processed 175/4000: image_174.jpg → real (Perturbed & Saved)
# Processed 176/4000: image_175.jpg → fake (Perturbed & Saved)
# Processed 177/4000: image_176.jpg → fake (Perturbed & Saved)
# Processed 178/4000: image_177.jpg → real (Perturbed & Saved)
# Processed 179/4000: image_178.jpg → real (Perturbed & Saved)
# Processed 180/4000: image_179.jpg → real (Perturbed & Saved)
# Processed 181/4000: image_180.jpg → fake (Perturbed & Saved)
# Processed 182/4000: image_181.jpg → real (Perturbed & Saved)
# Processed 183/4000: image_182.jpg → fake (Perturbed & Saved)
# Processed 184/4000: image_183.jpg → real (Perturbed & Saved)
# Processed 185/4000: image_184.jpg → fake (Perturbed & Saved)
# Processed 186/4000: image_185.jpg → fake (Perturbed & Saved)
# Processed 187/4000: image_186.jpg → fake (Perturbed & Saved)
# Processed 188/4000: image_187.jpg → real (Perturbed & Saved)
# Processed 189/4000: image_188.jpg → fake (Perturbed & Saved)
# Processed 190/4000: image_189.jpg → fake (Perturbed & Saved)
# Processed 191/4000: image_190.jpg → real (Perturbed & Saved)
# Processed 192/4000: image_191.jpg → real (Perturbed & Saved)
# Processed 193/4000: image_192.jpg → real (Perturbed & Saved)
# Processed 194/4000: image_193.jpg → real (Perturbed & Saved)
# Processed 195/4000: image_194.jpg → fake (Perturbed & Saved)
# Processed 196/4000: image_195.jpg → real (Perturbed & Saved)
# Processed 197/4000: image_196.jpg → real (Perturbed & Saved)
# Processed 198/4000: image_197.jpg → real (Perturbed & Saved)
# Processed 199/4000: image_198.jpg → real (Perturbed & Saved)
# Processed 200/4000: image_199.jpg → fake (Perturbed & Saved)
# Processed 201/4000: image_200.jpg → real (Perturbed & Saved)
# Processed 202/4000: image_201.jpg → fake (Perturbed & Saved)
# Processed 203/4000: image_202.jpg → real (Perturbed & Saved)
# Processed 204/4000: image_203.jpg → fake (Perturbed & Saved)
# Processed 205/4000: image_204.jpg → fake (Perturbed & Saved)
# Processed 206/4000: image_205.jpg → real (Perturbed & Saved)
# Processed 207/4000: image_206.jpg → fake (Perturbed & Saved)
# Processed 208/4000: image_207.jpg → real (Perturbed & Saved)
# Processed 209/4000: image_208.jpg → fake (Perturbed & Saved)
# Processed 210/4000: image_209.jpg → fake (Perturbed & Saved)
# Processed 211/4000: image_210.jpg → fake (Perturbed & Saved)
# Processed 212/4000: image_211.jpg → real (Perturbed & Saved)
# Processed 213/4000: image_212.jpg → fake (Perturbed & Saved)
# Processed 214/4000: image_213.jpg → real (Perturbed & Saved)
# Processed 215/4000: image_214.jpg → real (Perturbed & Saved)
# Processed 216/4000: image_215.jpg → fake (Perturbed & Saved)
# Processed 217/4000: image_216.jpg → fake (Perturbed & Saved)
# Processed 218/4000: image_217.jpg → real (Perturbed & Saved)
# Processed 219/4000: image_218.jpg → fake (Perturbed & Saved)
# Processed 220/4000: image_219.jpg → fake (Perturbed & Saved)
# Processed 221/4000: image_220.jpg → real (Perturbed & Saved)
# Processed 222/4000: image_221.jpg → real (Perturbed & Saved)
# Processed 223/4000: image_222.jpg → real (Perturbed & Saved)
# Processed 224/4000: image_223.jpg → real (Perturbed & Saved)
# Processed 225/4000: image_224.jpg → real (Perturbed & Saved)
# Processed 226/4000: image_225.jpg → fake (Perturbed & Saved)
# Processed 227/4000: image_226.jpg → fake (Perturbed & Saved)
# Processed 228/4000: image_227.jpg → real (Perturbed & Saved)
# Processed 229/4000: image_228.jpg → real (Perturbed & Saved)
# Processed 230/4000: image_229.jpg → fake (Perturbed & Saved)
# Processed 231/4000: image_230.jpg → real (Perturbed & Saved)
# Processed 232/4000: image_231.jpg → fake (Perturbed & Saved)
# Processed 233/4000: image_232.jpg → real (Perturbed & Saved)
# Processed 234/4000: image_233.jpg → real (Perturbed & Saved)
# Processed 235/4000: image_234.jpg → fake (Perturbed & Saved)
# Processed 236/4000: image_235.jpg → fake (Perturbed & Saved)
# Processed 237/4000: image_236.jpg → real (Perturbed & Saved)
# Processed 238/4000: image_237.jpg → fake (Perturbed & Saved)
# Processed 239/4000: image_238.jpg → fake (Perturbed & Saved)
# Processed 240/4000: image_239.jpg → real (Perturbed & Saved)
# Processed 241/4000: image_240.jpg → real (Perturbed & Saved)
# Processed 242/4000: image_241.jpg → fake (Perturbed & Saved)
# Processed 243/4000: image_242.jpg → fake (Perturbed & Saved)
# Processed 244/4000: image_243.jpg → fake (Perturbed & Saved)
# Processed 245/4000: image_244.jpg → real (Perturbed & Saved)
# Processed 246/4000: image_245.jpg → fake (Perturbed & Saved)
# Processed 247/4000: image_246.jpg → real (Perturbed & Saved)
# Processed 248/4000: image_247.jpg → fake (Perturbed & Saved)
# Processed 249/4000: image_248.jpg → real (Perturbed & Saved)
# Processed 250/4000: image_249.jpg → fake (Perturbed & Saved)
# Processed 251/4000: image_250.jpg → fake (Perturbed & Saved)
# Processed 252/4000: image_251.jpg → fake (Perturbed & Saved)
# Processed 253/4000: image_252.jpg → real (Perturbed & Saved)
# Processed 254/4000: image_253.jpg → real (Perturbed & Saved)
# Processed 255/4000: image_254.jpg → fake (Perturbed & Saved)
# Processed 256/4000: image_255.jpg → real (Perturbed & Saved)
# Processed 257/4000: image_256.jpg → fake (Perturbed & Saved)
# Processed 258/4000: image_257.jpg → fake (Perturbed & Saved)
# Processed 259/4000: image_258.jpg → real (Perturbed & Saved)
# Processed 260/4000: image_259.jpg → fake (Perturbed & Saved)
# Processed 261/4000: image_260.jpg → real (Perturbed & Saved)
# Processed 262/4000: image_261.jpg → fake (Perturbed & Saved)
# Processed 263/4000: image_262.jpg → real (Perturbed & Saved)
# Processed 264/4000: image_263.jpg → fake (Perturbed & Saved)
# Processed 265/4000: image_264.jpg → fake (Perturbed & Saved)
# Processed 266/4000: image_265.jpg → real (Perturbed & Saved)
# Processed 267/4000: image_266.jpg → fake (Perturbed & Saved)
# Processed 268/4000: image_267.jpg → fake (Perturbed & Saved)
# Processed 269/4000: image_268.jpg → real (Perturbed & Saved)
# Processed 270/4000: image_269.jpg → real (Perturbed & Saved)
# Processed 271/4000: image_270.jpg → real (Perturbed & Saved)
# Processed 272/4000: image_271.jpg → real (Perturbed & Saved)
# Processed 273/4000: image_272.jpg → fake (Perturbed & Saved)
# Processed 274/4000: image_273.jpg → fake (Perturbed & Saved)
# Processed 275/4000: image_274.jpg → fake (Perturbed & Saved)
# Processed 276/4000: image_275.jpg → real (Perturbed & Saved)
# Processed 277/4000: image_276.jpg → fake (Perturbed & Saved)
# Processed 278/4000: image_277.jpg → real (Perturbed & Saved)
# Processed 279/4000: image_278.jpg → real (Perturbed & Saved)
# Processed 280/4000: image_279.jpg → real (Perturbed & Saved)
# Processed 281/4000: image_280.jpg → real (Perturbed & Saved)
# Processed 282/4000: image_281.jpg → real (Perturbed & Saved)
# Processed 283/4000: image_282.jpg → real (Perturbed & Saved)
# Processed 284/4000: image_283.jpg → fake (Perturbed & Saved)
# Processed 285/4000: image_284.jpg → fake (Perturbed & Saved)
# Processed 286/4000: image_285.jpg → real (Perturbed & Saved)
# Processed 287/4000: image_286.jpg → real (Perturbed & Saved)
# Processed 288/4000: image_287.jpg → fake (Perturbed & Saved)
# Processed 289/4000: image_288.jpg → fake (Perturbed & Saved)
# Processed 290/4000: image_289.jpg → fake (Perturbed & Saved)
# Processed 291/4000: image_290.jpg → fake (Perturbed & Saved)
# Processed 292/4000: image_291.jpg → fake (Perturbed & Saved)
# Processed 293/4000: image_292.jpg → fake (Perturbed & Saved)
# Processed 294/4000: image_293.jpg → fake (Perturbed & Saved)
# Processed 295/4000: image_294.jpg → real (Perturbed & Saved)
# Processed 296/4000: image_295.jpg → fake (Perturbed & Saved)
# Processed 297/4000: image_296.jpg → real (Perturbed & Saved)
# Processed 298/4000: image_297.jpg → fake (Perturbed & Saved)
# Processed 299/4000: image_298.jpg → real (Perturbed & Saved)
# Processed 300/4000: image_299.jpg → real (Perturbed & Saved)
# Processed 301/4000: image_300.jpg → real (Perturbed & Saved)
# Processed 302/4000: image_301.jpg → real (Perturbed & Saved)
# Processed 303/4000: image_302.jpg → fake (Perturbed & Saved)
# Processed 304/4000: image_303.jpg → real (Perturbed & Saved)
# Processed 305/4000: image_304.jpg → fake (Perturbed & Saved)
# Processed 306/4000: image_305.jpg → fake (Perturbed & Saved)
# Processed 307/4000: image_306.jpg → real (Perturbed & Saved)
# Processed 308/4000: image_307.jpg → real (Perturbed & Saved)
# Processed 309/4000: image_308.jpg → fake (Perturbed & Saved)
# Processed 310/4000: image_309.jpg → fake (Perturbed & Saved)
# Processed 311/4000: image_310.jpg → fake (Perturbed & Saved)
# Processed 312/4000: image_311.jpg → fake (Perturbed & Saved)
# Processed 313/4000: image_312.jpg → fake (Perturbed & Saved)
# Processed 314/4000: image_313.jpg → fake (Perturbed & Saved)
# Processed 315/4000: image_314.jpg → fake (Perturbed & Saved)
# Processed 316/4000: image_315.jpg → fake (Perturbed & Saved)
# Processed 317/4000: image_316.jpg → real (Perturbed & Saved)
# Processed 318/4000: image_317.jpg → real (Perturbed & Saved)
# Processed 319/4000: image_318.jpg → fake (Perturbed & Saved)
# Processed 320/4000: image_319.jpg → fake (Perturbed & Saved)
# Processed 321/4000: image_320.jpg → fake (Perturbed & Saved)
# Processed 322/4000: image_321.jpg → real (Perturbed & Saved)
# Processed 323/4000: image_322.jpg → fake (Perturbed & Saved)
# Processed 324/4000: image_323.jpg → real (Perturbed & Saved)
# Processed 325/4000: image_324.jpg → fake (Perturbed & Saved)
# Processed 326/4000: image_325.jpg → real (Perturbed & Saved)
# Processed 327/4000: image_326.jpg → real (Perturbed & Saved)
# Processed 328/4000: image_327.jpg → real (Perturbed & Saved)
# Processed 329/4000: image_328.jpg → fake (Perturbed & Saved)
# Processed 330/4000: image_329.jpg → real (Perturbed & Saved)
# Processed 331/4000: image_330.jpg → real (Perturbed & Saved)
# Processed 332/4000: image_331.jpg → real (Perturbed & Saved)
# Processed 333/4000: image_332.jpg → fake (Perturbed & Saved)
# Processed 334/4000: image_333.jpg → real (Perturbed & Saved)
# Processed 335/4000: image_334.jpg → real (Perturbed & Saved)
# Processed 336/4000: image_335.jpg → fake (Perturbed & Saved)
# Processed 337/4000: image_336.jpg → real (Perturbed & Saved)
# Processed 338/4000: image_337.jpg → real (Perturbed & Saved)
# Processed 339/4000: image_338.jpg → real (Perturbed & Saved)
# Processed 340/4000: image_339.jpg → fake (Perturbed & Saved)
# Processed 341/4000: image_340.jpg → fake (Perturbed & Saved)
# Processed 342/4000: image_341.jpg → real (Perturbed & Saved)
# Processed 343/4000: image_342.jpg → real (Perturbed & Saved)
# Processed 344/4000: image_343.jpg → fake (Perturbed & Saved)
# Processed 345/4000: image_344.jpg → fake (Perturbed & Saved)
# Processed 346/4000: image_345.jpg → real (Perturbed & Saved)
# Processed 347/4000: image_346.jpg → fake (Perturbed & Saved)
# Processed 348/4000: image_347.jpg → fake (Perturbed & Saved)
# Processed 349/4000: image_348.jpg → real (Perturbed & Saved)
# Processed 350/4000: image_349.jpg → real (Perturbed & Saved)
# Processed 351/4000: image_350.jpg → real (Perturbed & Saved)
# Processed 352/4000: image_351.jpg → fake (Perturbed & Saved)
# Processed 353/4000: image_352.jpg → fake (Perturbed & Saved)
# Processed 354/4000: image_353.jpg → real (Perturbed & Saved)
# Processed 355/4000: image_354.jpg → real (Perturbed & Saved)
# Processed 356/4000: image_355.jpg → real (Perturbed & Saved)
# Processed 357/4000: image_356.jpg → fake (Perturbed & Saved)
# Processed 358/4000: image_357.jpg → real (Perturbed & Saved)
# Processed 359/4000: image_358.jpg → real (Perturbed & Saved)
# Processed 360/4000: image_359.jpg → fake (Perturbed & Saved)
# Processed 361/4000: image_360.jpg → real (Perturbed & Saved)
# Processed 362/4000: image_361.jpg → real (Perturbed & Saved)
# Processed 363/4000: image_362.jpg → fake (Perturbed & Saved)
# Processed 364/4000: image_363.jpg → fake (Perturbed & Saved)
# Processed 365/4000: image_364.jpg → fake (Perturbed & Saved)
# Processed 366/4000: image_365.jpg → fake (Perturbed & Saved)
# Processed 367/4000: image_366.jpg → real (Perturbed & Saved)
# Processed 368/4000: image_367.jpg → real (Perturbed & Saved)
# Processed 369/4000: image_368.jpg → real (Perturbed & Saved)
# Processed 370/4000: image_369.jpg → fake (Perturbed & Saved)
# Processed 371/4000: image_370.jpg → fake (Perturbed & Saved)
# Processed 372/4000: image_371.jpg → fake (Perturbed & Saved)
# Processed 373/4000: image_372.jpg → real (Perturbed & Saved)
# Processed 374/4000: image_373.jpg → real (Perturbed & Saved)
# Processed 375/4000: image_374.jpg → real (Perturbed & Saved)
# Processed 376/4000: image_375.jpg → real (Perturbed & Saved)
# Processed 377/4000: image_376.jpg → fake (Perturbed & Saved)
# Processed 378/4000: image_377.jpg → fake (Perturbed & Saved)
# Processed 379/4000: image_378.jpg → fake (Perturbed & Saved)
# Processed 380/4000: image_379.jpg → fake (Perturbed & Saved)
# Processed 381/4000: image_380.jpg → fake (Perturbed & Saved)
# Processed 382/4000: image_381.jpg → fake (Perturbed & Saved)
# Processed 383/4000: image_382.jpg → fake (Perturbed & Saved)
# Processed 384/4000: image_383.jpg → real (Perturbed & Saved)
# Processed 385/4000: image_384.jpg → real (Perturbed & Saved)
# Processed 386/4000: image_385.jpg → real (Perturbed & Saved)
# Processed 387/4000: image_386.jpg → real (Perturbed & Saved)
# Processed 388/4000: image_387.jpg → real (Perturbed & Saved)
# Processed 389/4000: image_388.jpg → fake (Perturbed & Saved)
# Processed 390/4000: image_389.jpg → real (Perturbed & Saved)
# Processed 391/4000: image_390.jpg → real (Perturbed & Saved)
# Processed 392/4000: image_391.jpg → real (Perturbed & Saved)
# Processed 393/4000: image_392.jpg → fake (Perturbed & Saved)
# Processed 394/4000: image_393.jpg → real (Perturbed & Saved)
# Processed 395/4000: image_394.jpg → fake (Perturbed & Saved)
# Processed 396/4000: image_395.jpg → fake (Perturbed & Saved)
# Processed 397/4000: image_396.jpg → real (Perturbed & Saved)
# Processed 398/4000: image_397.jpg → real (Perturbed & Saved)
# Processed 399/4000: image_398.jpg → real (Perturbed & Saved)
# Processed 400/4000: image_399.jpg → fake (Perturbed & Saved)
# Processed 401/4000: image_400.jpg → real (Perturbed & Saved)
# Processed 402/4000: image_401.jpg → real (Perturbed & Saved)
# Processed 403/4000: image_402.jpg → fake (Perturbed & Saved)
# Processed 404/4000: image_403.jpg → real (Perturbed & Saved)
# Processed 405/4000: image_404.jpg → real (Perturbed & Saved)
# Processed 406/4000: image_405.jpg → fake (Perturbed & Saved)
# Processed 407/4000: image_406.jpg → fake (Perturbed & Saved)
# Processed 408/4000: image_407.jpg → fake (Perturbed & Saved)
# Processed 409/4000: image_408.jpg → fake (Perturbed & Saved)
# Processed 410/4000: image_409.jpg → fake (Perturbed & Saved)
# Processed 411/4000: image_410.jpg → fake (Perturbed & Saved)
# Processed 412/4000: image_411.jpg → real (Perturbed & Saved)
# Processed 413/4000: image_412.jpg → real (Perturbed & Saved)
# Processed 414/4000: image_413.jpg → fake (Perturbed & Saved)
# Processed 415/4000: image_414.jpg → real (Perturbed & Saved)
# Processed 416/4000: image_415.jpg → real (Perturbed & Saved)
# Processed 417/4000: image_416.jpg → real (Perturbed & Saved)
# Processed 418/4000: image_417.jpg → fake (Perturbed & Saved)
# Processed 419/4000: image_418.jpg → real (Perturbed & Saved)
# Processed 420/4000: image_419.jpg → real (Perturbed & Saved)
# Processed 421/4000: image_420.jpg → real (Perturbed & Saved)
# Processed 422/4000: image_421.jpg → real (Perturbed & Saved)
# Processed 423/4000: image_422.jpg → real (Perturbed & Saved)
# Processed 424/4000: image_423.jpg → fake (Perturbed & Saved)
# Processed 425/4000: image_424.jpg → fake (Perturbed & Saved)
# Processed 426/4000: image_425.jpg → fake (Perturbed & Saved)
# Processed 427/4000: image_426.jpg → real (Perturbed & Saved)
# Processed 428/4000: image_427.jpg → real (Perturbed & Saved)
# Processed 429/4000: image_428.jpg → fake (Perturbed & Saved)
# Processed 430/4000: image_429.jpg → real (Perturbed & Saved)
# Processed 431/4000: image_430.jpg → fake (Perturbed & Saved)
# Processed 432/4000: image_431.jpg → fake (Perturbed & Saved)
# Processed 433/4000: image_432.jpg → real (Perturbed & Saved)
# Processed 434/4000: image_433.jpg → fake (Perturbed & Saved)
# Processed 435/4000: image_434.jpg → real (Perturbed & Saved)
# Processed 436/4000: image_435.jpg → real (Perturbed & Saved)
# Processed 437/4000: image_436.jpg → real (Perturbed & Saved)
# Processed 438/4000: image_437.jpg → real (Perturbed & Saved)
# Processed 439/4000: image_438.jpg → real (Perturbed & Saved)
# Processed 440/4000: image_439.jpg → fake (Perturbed & Saved)
# Processed 441/4000: image_440.jpg → fake (Perturbed & Saved)
# Processed 442/4000: image_441.jpg → real (Perturbed & Saved)
# Processed 443/4000: image_442.jpg → fake (Perturbed & Saved)
# Processed 444/4000: image_443.jpg → fake (Perturbed & Saved)
# Processed 445/4000: image_444.jpg → fake (Perturbed & Saved)
# Processed 446/4000: image_445.jpg → fake (Perturbed & Saved)
# Processed 447/4000: image_446.jpg → fake (Perturbed & Saved)
# Processed 448/4000: image_447.jpg → fake (Perturbed & Saved)
# Processed 449/4000: image_448.jpg → fake (Perturbed & Saved)
# Processed 450/4000: image_449.jpg → fake (Perturbed & Saved)
# Processed 451/4000: image_450.jpg → real (Perturbed & Saved)
# Processed 452/4000: image_451.jpg → fake (Perturbed & Saved)
# Processed 453/4000: image_452.jpg → real (Perturbed & Saved)
# Processed 454/4000: image_453.jpg → fake (Perturbed & Saved)
# Processed 455/4000: image_454.jpg → fake (Perturbed & Saved)
# Processed 456/4000: image_455.jpg → fake (Perturbed & Saved)
# Processed 457/4000: image_456.jpg → fake (Perturbed & Saved)
# Processed 458/4000: image_457.jpg → real (Perturbed & Saved)
# Processed 459/4000: image_458.jpg → real (Perturbed & Saved)
# Processed 460/4000: image_459.jpg → real (Perturbed & Saved)
# Processed 461/4000: image_460.jpg → fake (Perturbed & Saved)
# Processed 462/4000: image_461.jpg → fake (Perturbed & Saved)
# Processed 463/4000: image_462.jpg → fake (Perturbed & Saved)
# Processed 464/4000: image_463.jpg → real (Perturbed & Saved)
# Processed 465/4000: image_464.jpg → real (Perturbed & Saved)
# Processed 466/4000: image_465.jpg → fake (Perturbed & Saved)
# Processed 467/4000: image_466.jpg → fake (Perturbed & Saved)
# Processed 468/4000: image_467.jpg → fake (Perturbed & Saved)
# Processed 469/4000: image_468.jpg → real (Perturbed & Saved)
# Processed 470/4000: image_469.jpg → fake (Perturbed & Saved)
# Processed 471/4000: image_470.jpg → real (Perturbed & Saved)
# Processed 472/4000: image_471.jpg → fake (Perturbed & Saved)
# Processed 473/4000: image_472.jpg → real (Perturbed & Saved)
# Processed 474/4000: image_473.jpg → fake (Perturbed & Saved)
# Processed 475/4000: image_474.jpg → fake (Perturbed & Saved)
# Processed 476/4000: image_475.jpg → fake (Perturbed & Saved)
# Processed 477/4000: image_476.jpg → fake (Perturbed & Saved)
# Processed 478/4000: image_477.jpg → real (Perturbed & Saved)
# Processed 479/4000: image_478.jpg → real (Perturbed & Saved)
# Processed 480/4000: image_479.jpg → fake (Perturbed & Saved)
# Processed 481/4000: image_480.jpg → real (Perturbed & Saved)
# Processed 482/4000: image_481.jpg → fake (Perturbed & Saved)
# Processed 483/4000: image_482.jpg → fake (Perturbed & Saved)
# Processed 484/4000: image_483.jpg → fake (Perturbed & Saved)
# Processed 485/4000: image_484.jpg → real (Perturbed & Saved)
# Processed 486/4000: image_485.jpg → fake (Perturbed & Saved)
# Processed 487/4000: image_486.jpg → real (Perturbed & Saved)
# Processed 488/4000: image_487.jpg → fake (Perturbed & Saved)
# Processed 489/4000: image_488.jpg → fake (Perturbed & Saved)
# Processed 490/4000: image_489.jpg → real (Perturbed & Saved)
# Processed 491/4000: image_490.jpg → real (Perturbed & Saved)
# Processed 492/4000: image_491.jpg → fake (Perturbed & Saved)
# Processed 493/4000: image_492.jpg → real (Perturbed & Saved)
# Processed 494/4000: image_493.jpg → real (Perturbed & Saved)
# Processed 495/4000: image_494.jpg → real (Perturbed & Saved)
# Processed 496/4000: image_495.jpg → fake (Perturbed & Saved)
# Processed 497/4000: image_496.jpg → fake (Perturbed & Saved)
# Processed 498/4000: image_497.jpg → real (Perturbed & Saved)
# Processed 499/4000: image_498.jpg → real (Perturbed & Saved)
# Processed 500/4000: image_499.jpg → real (Perturbed & Saved)
# Processed 501/4000: image_500.jpg → fake (Perturbed & Saved)
# Processed 502/4000: image_501.jpg → fake (Perturbed & Saved)
# Processed 503/4000: image_502.jpg → real (Perturbed & Saved)
# Processed 504/4000: image_503.jpg → fake (Perturbed & Saved)
# Processed 505/4000: image_504.jpg → real (Perturbed & Saved)
# Processed 506/4000: image_505.jpg → fake (Perturbed & Saved)
# Processed 507/4000: image_506.jpg → real (Perturbed & Saved)
# Processed 508/4000: image_507.jpg → real (Perturbed & Saved)
# Processed 509/4000: image_508.jpg → real (Perturbed & Saved)
# Processed 510/4000: image_509.jpg → real (Perturbed & Saved)
# Processed 511/4000: image_510.jpg → fake (Perturbed & Saved)
# Processed 512/4000: image_511.jpg → real (Perturbed & Saved)
# Processed 513/4000: image_512.jpg → real (Perturbed & Saved)
# Processed 514/4000: image_513.jpg → fake (Perturbed & Saved)
# Processed 515/4000: image_514.jpg → fake (Perturbed & Saved)
# Processed 516/4000: image_515.jpg → fake (Perturbed & Saved)
# Processed 517/4000: image_516.jpg → real (Perturbed & Saved)
# Processed 518/4000: image_517.jpg → real (Perturbed & Saved)
# Processed 519/4000: image_518.jpg → fake (Perturbed & Saved)
# Processed 520/4000: image_519.jpg → real (Perturbed & Saved)
# Processed 521/4000: image_520.jpg → fake (Perturbed & Saved)
# Processed 522/4000: image_521.jpg → fake (Perturbed & Saved)
# Processed 523/4000: image_522.jpg → real (Perturbed & Saved)
# Processed 524/4000: image_523.jpg → fake (Perturbed & Saved)
# Processed 525/4000: image_524.jpg → real (Perturbed & Saved)
# Processed 526/4000: image_525.jpg → real (Perturbed & Saved)
# Processed 527/4000: image_526.jpg → real (Perturbed & Saved)
# Processed 528/4000: image_527.jpg → fake (Perturbed & Saved)
# Processed 529/4000: image_528.jpg → real (Perturbed & Saved)
# Processed 530/4000: image_529.jpg → fake (Perturbed & Saved)
# Processed 531/4000: image_530.jpg → fake (Perturbed & Saved)
# Processed 532/4000: image_531.jpg → real (Perturbed & Saved)
# Processed 533/4000: image_532.jpg → fake (Perturbed & Saved)
# Processed 534/4000: image_533.jpg → real (Perturbed & Saved)
# Processed 535/4000: image_534.jpg → real (Perturbed & Saved)
# Processed 536/4000: image_535.jpg → fake (Perturbed & Saved)
# Processed 537/4000: image_536.jpg → real (Perturbed & Saved)
# Processed 538/4000: image_537.jpg → fake (Perturbed & Saved)
# Processed 539/4000: image_538.jpg → fake (Perturbed & Saved)
# Processed 540/4000: image_539.jpg → real (Perturbed & Saved)
# Processed 541/4000: image_540.jpg → real (Perturbed & Saved)
# Processed 542/4000: image_541.jpg → fake (Perturbed & Saved)
# Processed 543/4000: image_542.jpg → real (Perturbed & Saved)
# Processed 544/4000: image_543.jpg → fake (Perturbed & Saved)
# Processed 545/4000: image_544.jpg → fake (Perturbed & Saved)
# Processed 546/4000: image_545.jpg → fake (Perturbed & Saved)
# Processed 547/4000: image_546.jpg → fake (Perturbed & Saved)
# Processed 548/4000: image_547.jpg → real (Perturbed & Saved)
# Processed 549/4000: image_548.jpg → fake (Perturbed & Saved)
# Processed 550/4000: image_549.jpg → fake (Perturbed & Saved)
# Processed 551/4000: image_550.jpg → fake (Perturbed & Saved)
# Processed 552/4000: image_551.jpg → fake (Perturbed & Saved)
# Processed 553/4000: image_552.jpg → fake (Perturbed & Saved)
# Processed 554/4000: image_553.jpg → fake (Perturbed & Saved)
# Processed 555/4000: image_554.jpg → real (Perturbed & Saved)
# Processed 556/4000: image_555.jpg → fake (Perturbed & Saved)
# Processed 557/4000: image_556.jpg → real (Perturbed & Saved)
# Processed 558/4000: image_557.jpg → real (Perturbed & Saved)
# Processed 559/4000: image_558.jpg → real (Perturbed & Saved)
# Processed 560/4000: image_559.jpg → fake (Perturbed & Saved)
# Processed 561/4000: image_560.jpg → real (Perturbed & Saved)
# Processed 562/4000: image_561.jpg → fake (Perturbed & Saved)
# Processed 563/4000: image_562.jpg → fake (Perturbed & Saved)
# Processed 564/4000: image_563.jpg → fake (Perturbed & Saved)
# Processed 565/4000: image_564.jpg → real (Perturbed & Saved)
# Processed 566/4000: image_565.jpg → fake (Perturbed & Saved)
# Processed 567/4000: image_566.jpg → fake (Perturbed & Saved)
# Processed 568/4000: image_567.jpg → real (Perturbed & Saved)
# Processed 569/4000: image_568.jpg → fake (Perturbed & Saved)
# Processed 570/4000: image_569.jpg → fake (Perturbed & Saved)
# Processed 571/4000: image_570.jpg → fake (Perturbed & Saved)
# Processed 572/4000: image_571.jpg → real (Perturbed & Saved)
# Processed 573/4000: image_572.jpg → fake (Perturbed & Saved)
# Processed 574/4000: image_573.jpg → fake (Perturbed & Saved)
# Processed 575/4000: image_574.jpg → fake (Perturbed & Saved)
# Processed 576/4000: image_575.jpg → fake (Perturbed & Saved)
# Processed 577/4000: image_576.jpg → fake (Perturbed & Saved)
# Processed 578/4000: image_577.jpg → fake (Perturbed & Saved)
# Processed 579/4000: image_578.jpg → real (Perturbed & Saved)
# Processed 580/4000: image_579.jpg → real (Perturbed & Saved)
# Processed 581/4000: image_580.jpg → fake (Perturbed & Saved)
# Processed 582/4000: image_581.jpg → real (Perturbed & Saved)
# Processed 583/4000: image_582.jpg → fake (Perturbed & Saved)
# Processed 584/4000: image_583.jpg → fake (Perturbed & Saved)
# Processed 585/4000: image_584.jpg → real (Perturbed & Saved)
# Processed 586/4000: image_585.jpg → real (Perturbed & Saved)
# Processed 587/4000: image_586.jpg → real (Perturbed & Saved)
# Processed 588/4000: image_587.jpg → fake (Perturbed & Saved)
# Processed 589/4000: image_588.jpg → real (Perturbed & Saved)
# Processed 590/4000: image_589.jpg → fake (Perturbed & Saved)
# Processed 591/4000: image_590.jpg → real (Perturbed & Saved)
# Processed 592/4000: image_591.jpg → fake (Perturbed & Saved)
# Processed 593/4000: image_592.jpg → fake (Perturbed & Saved)
# Processed 594/4000: image_593.jpg → real (Perturbed & Saved)
# Processed 595/4000: image_594.jpg → real (Perturbed & Saved)
# Processed 596/4000: image_595.jpg → real (Perturbed & Saved)
# Processed 597/4000: image_596.jpg → real (Perturbed & Saved)
# Processed 598/4000: image_597.jpg → real (Perturbed & Saved)
# Processed 599/4000: image_598.jpg → fake (Perturbed & Saved)
# Processed 600/4000: image_599.jpg → fake (Perturbed & Saved)
# Processed 601/4000: image_600.jpg → real (Perturbed & Saved)
# Processed 602/4000: image_601.jpg → real (Perturbed & Saved)
# Processed 603/4000: image_602.jpg → real (Perturbed & Saved)
# Processed 604/4000: image_603.jpg → real (Perturbed & Saved)
# Processed 605/4000: image_604.jpg → fake (Perturbed & Saved)
# Processed 606/4000: image_605.jpg → fake (Perturbed & Saved)
# Processed 607/4000: image_606.jpg → real (Perturbed & Saved)
# Processed 608/4000: image_607.jpg → real (Perturbed & Saved)
# Processed 609/4000: image_608.jpg → real (Perturbed & Saved)
# Processed 610/4000: image_609.jpg → fake (Perturbed & Saved)
# Processed 611/4000: image_610.jpg → fake (Perturbed & Saved)
# Processed 612/4000: image_611.jpg → fake (Perturbed & Saved)
# Processed 613/4000: image_612.jpg → fake (Perturbed & Saved)
# Processed 614/4000: image_613.jpg → fake (Perturbed & Saved)
# Processed 615/4000: image_614.jpg → fake (Perturbed & Saved)
# Processed 616/4000: image_615.jpg → fake (Perturbed & Saved)
# Processed 617/4000: image_616.jpg → fake (Perturbed & Saved)
# Processed 618/4000: image_617.jpg → real (Perturbed & Saved)
# Processed 619/4000: image_618.jpg → real (Perturbed & Saved)
# Processed 620/4000: image_619.jpg → fake (Perturbed & Saved)
# Processed 621/4000: image_620.jpg → fake (Perturbed & Saved)
# Processed 622/4000: image_621.jpg → fake (Perturbed & Saved)
# Processed 623/4000: image_622.jpg → real (Perturbed & Saved)
# Processed 624/4000: image_623.jpg → fake (Perturbed & Saved)
# Processed 625/4000: image_624.jpg → fake (Perturbed & Saved)
# Processed 626/4000: image_625.jpg → fake (Perturbed & Saved)
# Processed 627/4000: image_626.jpg → real (Perturbed & Saved)
# Processed 628/4000: image_627.jpg → real (Perturbed & Saved)
# Processed 629/4000: image_628.jpg → fake (Perturbed & Saved)
# Processed 630/4000: image_629.jpg → fake (Perturbed & Saved)
# Processed 631/4000: image_630.jpg → real (Perturbed & Saved)
# Processed 632/4000: image_631.jpg → real (Perturbed & Saved)
# Processed 633/4000: image_632.jpg → real (Perturbed & Saved)
# Processed 634/4000: image_633.jpg → fake (Perturbed & Saved)
# Processed 635/4000: image_634.jpg → real (Perturbed & Saved)
# Processed 636/4000: image_635.jpg → real (Perturbed & Saved)
# Processed 637/4000: image_636.jpg → real (Perturbed & Saved)
# Processed 638/4000: image_637.jpg → fake (Perturbed & Saved)
# Processed 639/4000: image_638.jpg → real (Perturbed & Saved)
# Processed 640/4000: image_639.jpg → fake (Perturbed & Saved)
# Processed 641/4000: image_640.jpg → real (Perturbed & Saved)
# Processed 642/4000: image_641.jpg → fake (Perturbed & Saved)
# Processed 643/4000: image_642.jpg → real (Perturbed & Saved)
# Processed 644/4000: image_643.jpg → real (Perturbed & Saved)
# Processed 645/4000: image_644.jpg → real (Perturbed & Saved)
# Processed 646/4000: image_645.jpg → real (Perturbed & Saved)
# Processed 647/4000: image_646.jpg → real (Perturbed & Saved)
# Processed 648/4000: image_647.jpg → real (Perturbed & Saved)
# Processed 649/4000: image_648.jpg → fake (Perturbed & Saved)
# Processed 650/4000: image_649.jpg → real (Perturbed & Saved)
# Processed 651/4000: image_650.jpg → fake (Perturbed & Saved)
# ...
# Processed 3763/4000: image_3762.jpg → fake (Copied without attack)
# Processed 3764/4000: image_3763.jpg → real (Copied without attack)
# Processed 3765/4000: image_3764.jpg → real (Copied without attack)
# Processed 3766/4000: image_3765.jpg → fake (Copied without attack)
# Processed 3767/4000: image_3766.jpg → fake (Copied without attack)
# Processed 3768/4000: image_3767.jpg → real (Copied without attack)
# Processed 3769/4000: image_3768.jpg → fake (Copied without attack)
# Processed 3770/4000: image_3769.jpg → real (Copied without attack)
# Processed 3771/4000: image_3770.jpg → real (Copied without attack)
# Processed 3772/4000: image_3771.jpg → fake (Copied without attack)
# Processed 3773/4000: image_3772.jpg → real (Copied without attack)
# Processed 3774/4000: image_3773.jpg → real (Copied without attack)
# Processed 3775/4000: image_3774.jpg → real (Copied without attack)
# Processed 3776/4000: image_3775.jpg → fake (Copied without attack)
# Processed 3777/4000: image_3776.jpg → fake (Copied without attack)
# Processed 3778/4000: image_3777.jpg → real (Copied without attack)
# Processed 3779/4000: image_3778.jpg → real (Copied without attack)
# Processed 3780/4000: image_3779.jpg → fake (Copied without attack)
# Processed 3781/4000: image_3780.jpg → real (Copied without attack)
# Processed 3782/4000: image_3781.jpg → real (Copied without attack)
# Processed 3783/4000: image_3782.jpg → real (Copied without attack)
# Processed 3784/4000: image_3783.jpg → fake (Copied without attack)
# Processed 3785/4000: image_3784.jpg → real (Copied without attack)
# Processed 3786/4000: image_3785.jpg → fake (Copied without attack)
# Processed 3787/4000: image_3786.jpg → fake (Copied without attack)
# Processed 3788/4000: image_3787.jpg → fake (Copied without attack)
# Processed 3789/4000: image_3788.jpg → real (Copied without attack)
# Processed 3790/4000: image_3789.jpg → real (Copied without attack)
# Processed 3791/4000: image_3790.jpg → real (Copied without attack)
# Processed 3792/4000: image_3791.jpg → fake (Copied without attack)
# Processed 3793/4000: image_3792.jpg → fake (Copied without attack)
# Processed 3794/4000: image_3793.jpg → real (Copied without attack)
# Processed 3795/4000: image_3794.jpg → fake (Copied without attack)
# Processed 3796/4000: image_3795.jpg → fake (Copied without attack)
# Processed 3797/4000: image_3796.jpg → real (Copied without attack)
# Processed 3798/4000: image_3797.jpg → real (Copied without attack)
# Processed 3799/4000: image_3798.jpg → fake (Copied without attack)
# Processed 3800/4000: image_3799.jpg → fake (Copied without attack)
# Processed 3801/4000: image_3800.jpg → fake (Copied without attack)
# Processed 3802/4000: image_3801.jpg → fake (Copied without attack)
# Processed 3803/4000: image_3802.jpg → real (Copied without attack)
# Processed 3804/4000: image_3803.jpg → real (Copied without attack)
# Processed 3805/4000: image_3804.jpg → fake (Copied without attack)
# Processed 3806/4000: image_3805.jpg → fake (Copied without attack)
# Processed 3807/4000: image_3806.jpg → real (Copied without attack)
# Processed 3808/4000: image_3807.jpg → fake (Copied without attack)
# Processed 3809/4000: image_3808.jpg → real (Copied without attack)
# Processed 3810/4000: image_3809.jpg → fake (Copied without attack)
# Processed 3811/4000: image_3810.jpg → real (Copied without attack)
# Processed 3812/4000: image_3811.jpg → real (Copied without attack)
# Processed 3813/4000: image_3812.jpg → real (Copied without attack)
# Processed 3814/4000: image_3813.jpg → fake (Copied without attack)
# Processed 3815/4000: image_3814.jpg → fake (Copied without attack)
# Processed 3816/4000: image_3815.jpg → real (Copied without attack)
# Processed 3817/4000: image_3816.jpg → fake (Copied without attack)
# Processed 3818/4000: image_3817.jpg → real (Copied without attack)
# Processed 3819/4000: image_3818.jpg → fake (Copied without attack)
# Processed 3820/4000: image_3819.jpg → fake (Copied without attack)
# Processed 3821/4000: image_3820.jpg → fake (Copied without attack)
# Processed 3822/4000: image_3821.jpg → fake (Copied without attack)
# Processed 3823/4000: image_3822.jpg → real (Copied without attack)
# Processed 3824/4000: image_3823.jpg → real (Copied without attack)
# Processed 3825/4000: image_3824.jpg → real (Copied without attack)
# Processed 3826/4000: image_3825.jpg → real (Copied without attack)
# Processed 3827/4000: image_3826.jpg → real (Copied without attack)
# Processed 3828/4000: image_3827.jpg → fake (Copied without attack)
# Processed 3829/4000: image_3828.jpg → real (Copied without attack)
# Processed 3830/4000: image_3829.jpg → fake (Copied without attack)
# Processed 3831/4000: image_3830.jpg → fake (Copied without attack)
# Processed 3832/4000: image_3831.jpg → fake (Copied without attack)
# Processed 3833/4000: image_3832.jpg → fake (Copied without attack)
# Processed 3834/4000: image_3833.jpg → fake (Copied without attack)
# Processed 3835/4000: image_3834.jpg → real (Copied without attack)
# Processed 3836/4000: image_3835.jpg → real (Copied without attack)
# Processed 3837/4000: image_3836.jpg → real (Copied without attack)
# Processed 3838/4000: image_3837.jpg → real (Copied without attack)
# Processed 3839/4000: image_3838.jpg → real (Copied without attack)
# Processed 3840/4000: image_3839.jpg → real (Copied without attack)
# Processed 3841/4000: image_3840.jpg → real (Copied without attack)
# Processed 3842/4000: image_3841.jpg → fake (Copied without attack)
# Processed 3843/4000: image_3842.jpg → fake (Copied without attack)
# Processed 3844/4000: image_3843.jpg → fake (Copied without attack)
# Processed 3845/4000: image_3844.jpg → real (Copied without attack)
# Processed 3846/4000: image_3845.jpg → fake (Copied without attack)
# Processed 3847/4000: image_3846.jpg → real (Copied without attack)
# Processed 3848/4000: image_3847.jpg → real (Copied without attack)
# Processed 3849/4000: image_3848.jpg → real (Copied without attack)
# Processed 3850/4000: image_3849.jpg → real (Copied without attack)
# Processed 3851/4000: image_3850.jpg → fake (Copied without attack)
# Processed 3852/4000: image_3851.jpg → real (Copied without attack)
# Processed 3853/4000: image_3852.jpg → real (Copied without attack)
# Processed 3854/4000: image_3853.jpg → fake (Copied without attack)
# Processed 3855/4000: image_3854.jpg → fake (Copied without attack)
# Processed 3856/4000: image_3855.jpg → fake (Copied without attack)
# Processed 3857/4000: image_3856.jpg → fake (Copied without attack)
# Processed 3858/4000: image_3857.jpg → real (Copied without attack)
# Processed 3859/4000: image_3858.jpg → fake (Copied without attack)
# Processed 3860/4000: image_3859.jpg → real (Copied without attack)
# Processed 3861/4000: image_3860.jpg → real (Copied without attack)
# Processed 3862/4000: image_3861.jpg → fake (Copied without attack)
# Processed 3863/4000: image_3862.jpg → fake (Copied without attack)
# Processed 3864/4000: image_3863.jpg → fake (Copied without attack)
# Processed 3865/4000: image_3864.jpg → fake (Copied without attack)
# Processed 3866/4000: image_3865.jpg → fake (Copied without attack)
# Processed 3867/4000: image_3866.jpg → fake (Copied without attack)
# Processed 3868/4000: image_3867.jpg → real (Copied without attack)
# Processed 3869/4000: image_3868.jpg → fake (Copied without attack)
# Processed 3870/4000: image_3869.jpg → fake (Copied without attack)
# Processed 3871/4000: image_3870.jpg → real (Copied without attack)
# Processed 3872/4000: image_3871.jpg → fake (Copied without attack)
# Processed 3873/4000: image_3872.jpg → real (Copied without attack)
# Processed 3874/4000: image_3873.jpg → fake (Copied without attack)
# Processed 3875/4000: image_3874.jpg → fake (Copied without attack)
# Processed 3876/4000: image_3875.jpg → real (Copied without attack)
# Processed 3877/4000: image_3876.jpg → real (Copied without attack)
# Processed 3878/4000: image_3877.jpg → fake (Copied without attack)
# Processed 3879/4000: image_3878.jpg → fake (Copied without attack)
# Processed 3880/4000: image_3879.jpg → real (Copied without attack)
# Processed 3881/4000: image_3880.jpg → fake (Copied without attack)
# Processed 3882/4000: image_3881.jpg → real (Copied without attack)
# Processed 3883/4000: image_3882.jpg → real (Copied without attack)
# Processed 3884/4000: image_3883.jpg → real (Copied without attack)
# Processed 3885/4000: image_3884.jpg → real (Copied without attack)
# Processed 3886/4000: image_3885.jpg → real (Copied without attack)
# Processed 3887/4000: image_3886.jpg → fake (Copied without attack)
# Processed 3888/4000: image_3887.jpg → real (Copied without attack)
# Processed 3889/4000: image_3888.jpg → fake (Copied without attack)
# Processed 3890/4000: image_3889.jpg → fake (Copied without attack)
# Processed 3891/4000: image_3890.jpg → fake (Copied without attack)
# Processed 3892/4000: image_3891.jpg → real (Copied without attack)
# Processed 3893/4000: image_3892.jpg → real (Copied without attack)
# Processed 3894/4000: image_3893.jpg → real (Copied without attack)
# Processed 3895/4000: image_3894.jpg → fake (Copied without attack)
# Processed 3896/4000: image_3895.jpg → real (Copied without attack)
# Processed 3897/4000: image_3896.jpg → fake (Copied without attack)
# Processed 3898/4000: image_3897.jpg → real (Copied without attack)
# Processed 3899/4000: image_3898.jpg → real (Copied without attack)
# Processed 3900/4000: image_3899.jpg → real (Copied without attack)
# Processed 3901/4000: image_3900.jpg → real (Copied without attack)
# Processed 3902/4000: image_3901.jpg → real (Copied without attack)
# Processed 3903/4000: image_3902.jpg → real (Copied without attack)
# Processed 3904/4000: image_3903.jpg → fake (Copied without attack)
# Processed 3905/4000: image_3904.jpg → real (Copied without attack)
# Processed 3906/4000: image_3905.jpg → fake (Copied without attack)
# Processed 3907/4000: image_3906.jpg → fake (Copied without attack)
# Processed 3908/4000: image_3907.jpg → fake (Copied without attack)
# Processed 3909/4000: image_3908.jpg → real (Copied without attack)
# Processed 3910/4000: image_3909.jpg → real (Copied without attack)
# Processed 3911/4000: image_3910.jpg → fake (Copied without attack)
# Processed 3912/4000: image_3911.jpg → fake (Copied without attack)
# Processed 3913/4000: image_3912.jpg → real (Copied without attack)
# Processed 3914/4000: image_3913.jpg → real (Copied without attack)
# Processed 3915/4000: image_3914.jpg → real (Copied without attack)
# Processed 3916/4000: image_3915.jpg → real (Copied without attack)
# Processed 3917/4000: image_3916.jpg → fake (Copied without attack)
# Processed 3918/4000: image_3917.jpg → real (Copied without attack)
# Processed 3919/4000: image_3918.jpg → fake (Copied without attack)
# Processed 3920/4000: image_3919.jpg → fake (Copied without attack)
# Processed 3921/4000: image_3920.jpg → real (Copied without attack)
# Processed 3922/4000: image_3921.jpg → real (Copied without attack)
# Processed 3923/4000: image_3922.jpg → fake (Copied without attack)
# Processed 3924/4000: image_3923.jpg → fake (Copied without attack)
# Processed 3925/4000: image_3924.jpg → fake (Copied without attack)
# Processed 3926/4000: image_3925.jpg → real (Copied without attack)
# Processed 3927/4000: image_3926.jpg → real (Copied without attack)
# Processed 3928/4000: image_3927.jpg → fake (Copied without attack)
# Processed 3929/4000: image_3928.jpg → real (Copied without attack)
# Processed 3930/4000: image_3929.jpg → real (Copied without attack)
# Processed 3931/4000: image_3930.jpg → real (Copied without attack)
# Processed 3932/4000: image_3931.jpg → fake (Copied without attack)
# Processed 3933/4000: image_3932.jpg → real (Copied without attack)
# Processed 3934/4000: image_3933.jpg → fake (Copied without attack)
# Processed 3935/4000: image_3934.jpg → real (Copied without attack)
# Processed 3936/4000: image_3935.jpg → real (Copied without attack)
# Processed 3937/4000: image_3936.jpg → fake (Copied without attack)
# Processed 3938/4000: image_3937.jpg → real (Copied without attack)
# Processed 3939/4000: image_3938.jpg → fake (Copied without attack)
# Processed 3940/4000: image_3939.jpg → real (Copied without attack)
# Processed 3941/4000: image_3940.jpg → fake (Copied without attack)
# Processed 3942/4000: image_3941.jpg → fake (Copied without attack)
# Processed 3943/4000: image_3942.jpg → fake (Copied without attack)
# Processed 3944/4000: image_3943.jpg → fake (Copied without attack)
# Processed 3945/4000: image_3944.jpg → real (Copied without attack)
# Processed 3946/4000: image_3945.jpg → fake (Copied without attack)
# Processed 3947/4000: image_3946.jpg → real (Copied without attack)
# Processed 3948/4000: image_3947.jpg → fake (Copied without attack)
# Processed 3949/4000: image_3948.jpg → fake (Copied without attack)
# Processed 3950/4000: image_3949.jpg → real (Copied without attack)
# Processed 3951/4000: image_3950.jpg → real (Copied without attack)
# Processed 3952/4000: image_3951.jpg → fake (Copied without attack)
# Processed 3953/4000: image_3952.jpg → fake (Copied without attack)
# Processed 3954/4000: image_3953.jpg → fake (Copied without attack)
# Processed 3955/4000: image_3954.jpg → real (Copied without attack)
# Processed 3956/4000: image_3955.jpg → fake (Copied without attack)
# Processed 3957/4000: image_3956.jpg → real (Copied without attack)
# Processed 3958/4000: image_3957.jpg → fake (Copied without attack)
# Processed 3959/4000: image_3958.jpg → real (Copied without attack)
# Processed 3960/4000: image_3959.jpg → real (Copied without attack)
# Processed 3961/4000: image_3960.jpg → real (Copied without attack)
# Processed 3962/4000: image_3961.jpg → real (Copied without attack)
# Processed 3963/4000: image_3962.jpg → real (Copied without attack)
# Processed 3964/4000: image_3963.jpg → real (Copied without attack)
# Processed 3965/4000: image_3964.jpg → fake (Copied without attack)
# Processed 3966/4000: image_3965.jpg → fake (Copied without attack)
# Processed 3967/4000: image_3966.jpg → real (Copied without attack)
# Processed 3968/4000: image_3967.jpg → real (Copied without attack)
# Processed 3969/4000: image_3968.jpg → real (Copied without attack)
# Processed 3970/4000: image_3969.jpg → real (Copied without attack)
# Processed 3971/4000: image_3970.jpg → fake (Copied without attack)
# Processed 3972/4000: image_3971.jpg → real (Copied without attack)
# Processed 3973/4000: image_3972.jpg → real (Copied without attack)
# Processed 3974/4000: image_3973.jpg → fake (Copied without attack)
# Processed 3975/4000: image_3974.jpg → real (Copied without attack)
# Processed 3976/4000: image_3975.jpg → fake (Copied without attack)
# Processed 3977/4000: image_3976.jpg → fake (Copied without attack)
# Processed 3978/4000: image_3977.jpg → real (Copied without attack)
# Processed 3979/4000: image_3978.jpg → real (Copied without attack)
# Processed 3980/4000: image_3979.jpg → fake (Copied without attack)
# Processed 3981/4000: image_3980.jpg → fake (Copied without attack)
# Processed 3982/4000: image_3981.jpg → fake (Copied without attack)
# Processed 3983/4000: image_3982.jpg → real (Copied without attack)
# Processed 3984/4000: image_3983.jpg → fake (Copied without attack)
# Processed 3985/4000: image_3984.jpg → real (Copied without attack)
# Processed 3986/4000: image_3985.jpg → real (Copied without attack)
# Processed 3987/4000: image_3986.jpg → fake (Copied without attack)
# Processed 3988/4000: image_3987.jpg → real (Copied without attack)
# Processed 3989/4000: image_3988.jpg → fake (Copied without attack)
# Processed 3990/4000: image_3989.jpg → real (Copied without attack)
# Processed 3991/4000: image_3990.jpg → real (Copied without attack)
# Processed 3992/4000: image_3991.jpg → real (Copied without attack)
# Processed 3993/4000: image_3992.jpg → fake (Copied without attack)
# Processed 3994/4000: image_3993.jpg → real (Copied without attack)
# Processed 3995/4000: image_3994.jpg → fake (Copied without attack)
# Processed 3996/4000: image_3995.jpg → real (Copied without attack)
# Processed 3997/4000: image_3996.jpg → real (Copied without attack)
# Processed 3998/4000: image_3997.jpg → real (Copied without attack)
# Processed 3999/4000: image_3998.jpg → fake (Copied without attack)
# Processed 4000/4000: image_3999.jpg → real (Copied without attack)

# %%
data_config = timm.data.resolve_model_data_config(model)
train_transforms = timm.data.create_transform(**data_config, is_training=True)
test_transforms = timm.data.create_transform(**data_config, is_training=False)

# %%
import timm
import torch.nn as nn
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ✅ Load TinyViT model
model = timm.create_model("tiny_vit_21m_224.dist_in22k", pretrained=True)

# 🔍 Check model architecture
print("Original Model Structure:\n", model)

# 🔹 Identify correct classifier layer and modify it
if hasattr(model, "head"):
    if isinstance(model.head, nn.Linear):
        model.head = nn.Linear(model.head.in_features, 1)  # Direct Linear layer case
    elif hasattr(model.head, "fc"):
        model.head.fc = nn.Linear(model.head.fc.in_features, 1)  # If head has fc layer
    elif isinstance(model.head, nn.Sequential):
        model.head[-1] = nn.Linear(model.head[-1].in_features, 1)  # If Sequential
    else:
        raise ValueError("Unknown model head structure! Modify manually.")
else:
    raise ValueError("Model has no head attribute!")

# ✅ Move model to GPU
model = model.to(device)

# 🛠 Debugging: Test a forward pass
with torch.no_grad():
    dummy_input = torch.randn(1, 3, 224, 224).to(device)  # Create a fake image batch
    output = model(dummy_input)
    print("\n🟢 Model Output (Raw):", output)
    print("🟢 Output Shape:", output.shape)  # Expected shape: [1, 1]
# Out:
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# Original Model Structure:
#  TinyVit(
#   (patch_embed): PatchEmbed(
#     (conv1): ConvNorm(
#       (conv): Conv2d(3, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (act): GELU(approximate='none')
#     (conv2): ConvNorm(
#       (conv): Conv2d(48, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (stages): Sequential(
#     (0): ConvLayer(
#       (blocks): Sequential(
#         (0): MBConv(
#           (conv1): ConvNorm(
#             (conv): Conv2d(96, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act1): GELU(approximate='none')
#           (conv2): ConvNorm(
#             (conv): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act2): GELU(approximate='none')
#           (conv3): ConvNorm(
#             (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act3): GELU(approximate='none')
#           (drop_path): Identity()
#         )
#         (1): MBConv(
#           (conv1): ConvNorm(
#             (conv): Conv2d(96, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act1): GELU(approximate='none')
#           (conv2): ConvNorm(
#             (conv): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act2): GELU(approximate='none')
#           (conv3): ConvNorm(
#             (conv): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (act3): GELU(approximate='none')
#           (drop_path): DropPath(drop_prob=0.018)
#         )
#       )
#     )
#     (1): TinyVitStage(
#       dim=192, depth=2
#       (downsample): PatchMerging(
#         (conv1): ConvNorm(
#           (conv): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act1): GELU(approximate='none')
#         (conv2): ConvNorm(
#           (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act2): GELU(approximate='none')
#         (conv3): ConvNorm(
#           (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (blocks): Sequential(
#         (0): TinyVitBlock(
#           dim=192, num_heads=6, window_size=7, mlp_ratio=4.0
#           (attn): Attention(
#             (norm): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#             (qkv): Linear(in_features=192, out_features=576, bias=True)
#             (proj): Linear(in_features=192, out_features=192, bias=True)
#           )
#           (drop_path1): DropPath(drop_prob=0.036)
#           (mlp): NormMlp(
#             (norm): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=192, out_features=768, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=768, out_features=192, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.036)
#           (local_conv): ConvNorm(
#             (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): TinyVitBlock(
#           dim=192, num_heads=6, window_size=7, mlp_ratio=4.0
#           (attn): Attention(
#             (norm): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#             (qkv): Linear(in_features=192, out_features=576, bias=True)
#             (proj): Linear(in_features=192, out_features=192, bias=True)
#           )
#           (drop_path1): DropPath(drop_prob=0.055)
#           (mlp): NormMlp(
#             (norm): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=192, out_features=768, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=768, out_features=192, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.055)
#           (local_conv): ConvNorm(
#             (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (2): TinyVitStage(
#       dim=384, depth=6
#       (downsample): PatchMerging(
#         (conv1): ConvNorm(
#           (conv): Conv2d(192, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act1): GELU(approximate='none')
#         (conv2): ConvNorm(
#           (conv): Conv2d(384, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=384, bias=False)
#           (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act2): GELU(approximate='none')
#         (conv3): ConvNorm(
#           (conv): Conv2d(384, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (blocks): Sequential(
#         (0): TinyVitBlock(
#           dim=384, num_heads=12, window_size=14, mlp_ratio=4.0
#           (attn): Attention(
#             (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             (qkv): Linear(in_features=384, out_features=1152, bias=True)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#           )
#           (drop_path1): DropPath(drop_prob=0.073)
#           (mlp): NormMlp(
#             (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.073)
#           (local_conv): ConvNorm(
#             (conv): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): TinyVitBlock(
#           dim=384, num_heads=12, window_size=14, mlp_ratio=4.0
#           (attn): Attention(
#             (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             (qkv): Linear(in_features=384, out_features=1152, bias=True)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#           )
#           (drop_path1): DropPath(drop_prob=0.091)
#           (mlp): NormMlp(
#             (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.091)
#           (local_conv): ConvNorm(
#             (conv): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (2): TinyVitBlock(
#           dim=384, num_heads=12, window_size=14, mlp_ratio=4.0
#           (attn): Attention(
#             (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             (qkv): Linear(in_features=384, out_features=1152, bias=True)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#           )
#           (drop_path1): DropPath(drop_prob=0.109)
#           (mlp): NormMlp(
#             (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.109)
#           (local_conv): ConvNorm(
#             (conv): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (3): TinyVitBlock(
#           dim=384, num_heads=12, window_size=14, mlp_ratio=4.0
#           (attn): Attention(
#             (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             (qkv): Linear(in_features=384, out_features=1152, bias=True)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#           )
#           (drop_path1): DropPath(drop_prob=0.127)
#           (mlp): NormMlp(
#             (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.127)
#           (local_conv): ConvNorm(
#             (conv): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (4): TinyVitBlock(
#           dim=384, num_heads=12, window_size=14, mlp_ratio=4.0
#           (attn): Attention(
#             (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             (qkv): Linear(in_features=384, out_features=1152, bias=True)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#           )
#           (drop_path1): DropPath(drop_prob=0.145)
#           (mlp): NormMlp(
#             (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.145)
#           (local_conv): ConvNorm(
#             (conv): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (5): TinyVitBlock(
#           dim=384, num_heads=12, window_size=14, mlp_ratio=4.0
#           (attn): Attention(
#             (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             (qkv): Linear(in_features=384, out_features=1152, bias=True)
#             (proj): Linear(in_features=384, out_features=384, bias=True)
#           )
#           (drop_path1): DropPath(drop_prob=0.164)
#           (mlp): NormMlp(
#             (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=384, out_features=1536, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=1536, out_features=384, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.164)
#           (local_conv): ConvNorm(
#             (conv): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#             (bn): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#     (3): TinyVitStage(
#       dim=576, depth=2
#       (downsample): PatchMerging(
#         (conv1): ConvNorm(
#           (conv): Conv2d(384, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act1): GELU(approximate='none')
#         (conv2): ConvNorm(
#           (conv): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#           (bn): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (act2): GELU(approximate='none')
#         (conv3): ConvNorm(
#           (conv): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (blocks): Sequential(
#         (0): TinyVitBlock(
#           dim=576, num_heads=18, window_size=7, mlp_ratio=4.0
#           (attn): Attention(
#             (norm): LayerNorm((576,), eps=1e-05, elementwise_affine=True)
#             (qkv): Linear(in_features=576, out_features=1728, bias=True)
#             (proj): Linear(in_features=576, out_features=576, bias=True)
#           )
#           (drop_path1): DropPath(drop_prob=0.182)
#           (mlp): NormMlp(
#             (norm): LayerNorm((576,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=576, out_features=2304, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=2304, out_features=576, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.182)
#           (local_conv): ConvNorm(
#             (conv): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#             (bn): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): TinyVitBlock(
#           dim=576, num_heads=18, window_size=7, mlp_ratio=4.0
#           (attn): Attention(
#             (norm): LayerNorm((576,), eps=1e-05, elementwise_affine=True)
#             (qkv): Linear(in_features=576, out_features=1728, bias=True)
#             (proj): Linear(in_features=576, out_features=576, bias=True)
#           )
#           (drop_path1): DropPath(drop_prob=0.200)
#           (mlp): NormMlp(
#             (norm): LayerNorm((576,), eps=1e-05, elementwise_affine=True)
#             (fc1): Linear(in_features=576, out_features=2304, bias=True)
#             (act): GELU(approximate='none')
#             (drop1): Dropout(p=0.0, inplace=False)
#             (fc2): Linear(in_features=2304, out_features=576, bias=True)
#             (drop2): Dropout(p=0.0, inplace=False)
#           )
#           (drop_path2): DropPath(drop_prob=0.200)
#           (local_conv): ConvNorm(
#             (conv): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#             (bn): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#       )
#     )
#   )
#   (head): NormMlpClassifierHead(
#     (global_pool): SelectAdaptivePool2d(pool_type=avg, flatten=Identity())
#     (norm): LayerNorm2d((576,), eps=1e-05, elementwise_affine=True)
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#     (pre_logits): Identity()
#     (drop): Dropout(p=0.0, inplace=False)
#     (fc): Linear(in_features=576, out_features=21841, bias=True)
#   )
# )
#
# 🟢 Model Output (Raw): tensor([[-0.0232]], device='cuda:0')
# 🟢 Output Shape: torch.Size([1, 1])

# %%
DATASET_PATH =' /kaggle/working/train ' # Update if needed
REAL_PATH = os.path.join(DATASET_PATH, "real")
FAKE_PATH = os.path.join(DATASET_PATH, "fake")

# %%
class CustomDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.images = glob.glob(f"{root_dir}/real/*.jpg") + glob.glob(
            f"{root_dir}/fake/*.jpg"
        )
        self.labels = [0] * len(glob.glob(f"{root_dir}/real/*.jpg")) + [1] * len(
            glob.glob(f"{root_dir}/fake/*.jpg")
        )
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        img = Image.open(img_path)
        if self.transform:
            img = self.transform(img)
        label = self.labels[idx]
        return img, torch.tensor(label, dtype=torch.float32)

# %%
train_ds = CustomDataset(root_dir="/kaggle/working/train", transform=train_transforms)
#test_ds = CustomDataset(root_dir="/kaggle/wroking/cifake-real-and-ai-generated-synthetic-images/test", transform=test_transforms)

# %%
len(train_ds)
# Out:
# 4000

# %%
train_loader = DataLoader(
    train_ds, batch_size=32, shuffle=True, num_workers=4, pin_memory=True
)
'''test_loader = DataLoader(
    test_ds, batch_size=32, shuffle=False, num_workers=4, pin_memory=True
)'''
# Out:
# 'test_loader = DataLoader(\n    test_ds, batch_size=32, shuffle=False, num_workers=4, pin_memory=True\n)'

# %%
epochs =5
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)
scheduler = CosineAnnealingLR(optimizer, T_max=epochs)

for epoch in range(epochs):
    model.train()
    for i, (images, labels) in enumerate(train_loader):
        labels = labels.view(-1, 1).float()  # Ensure correct shape

        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()

        outputs = model(images).view(-1, 1)  # Ensure model outputs the correct shape
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        if i % 1000 == 0:
            print(f"Epoch: {epoch}, Iteration: {i}, Loss: {loss.item()}")

    scheduler.step()
    print(f"Epoch: {epoch}, Loss: {loss.item()}, LR: {scheduler.get_last_lr()}")
# Out:
# Epoch: 0, Iteration: 0, Loss: 0.7222620248794556
# Epoch: 0, Loss: 0.4538324177265167, LR: [9.045084971874738e-05]
# Epoch: 1, Iteration: 0, Loss: 0.625525951385498
# Epoch: 1, Loss: 0.40043485164642334, LR: [6.545084971874737e-05]
# Epoch: 2, Iteration: 0, Loss: 0.4730417728424072
# Epoch: 2, Loss: 0.534018874168396, LR: [3.454915028125263e-05]
# Epoch: 3, Iteration: 0, Loss: 0.33211445808410645
# Epoch: 3, Loss: 0.39600473642349243, LR: [9.549150281252631e-06]
# Epoch: 4, Iteration: 0, Loss: 0.28870677947998047
# Epoch: 4, Loss: 0.20295949280261993, LR: [0.0]

# %%
save_dir = "/kaggle/working/model"
os.makedirs(save_dir, exist_ok=True)  # Ensure the directory exists

# Define model save path
model_path = os.path.join(save_dir, "tiny_vit_modified.pth")

# Save the model
torch.save(model.state_dict(), model_path)

print(f"✅ Model saved at: {model_path}")
# Out:
# ✅ Model saved at: /kaggle/working/model/tiny_vit_modified.pth
